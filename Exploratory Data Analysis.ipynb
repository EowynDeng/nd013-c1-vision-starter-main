# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
from utils import get_dataset
import glob
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import tensorflow as tf

# %matplotlib inline

# %%
dataset = get_dataset("/home/workspace/data/train/*.tfrecord")
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 86
# WARNING:tensorflow:From /data/virtual_envs/sdc-c1-gpu-augment/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# ...

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_images` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_images(batch):
    color_map = {1: 'red', 2: 'blue', 4: 'green'}
    fig, ax = plt.subplots()
    image = batch['image'].numpy()
    ax.imshow(image)
    h, w = image.shape[:2]
    boxes = batch['groundtruth_boxes'].numpy()
    classes = batch['groundtruth_classes'].numpy()
    for box, label in zip(boxes, classes):
        y1, x1, y2, x2 = box
        x1 *= w
        x2 *= w
        y1 *= h
        y2 *= h
        box_w = x2 - x1
        box_h = y2 - y1
        draw = patches.Rectangle((x1, y1), box_w, box_h, facecolor='none', edgecolor=color_map[label], linewidth=2)
        ax.add_patch(draw)

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
# Display 10 random images in dataset
plt.figure(figsize=(10, 10))
for i in range(10):
    for batch in dataset.shuffle(75).take(1):
        display_images(batch)
plt.show()

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...

# %%
train_data_list = glob.glob("data/train/*.tfrecord")

veh_count = 0
ped_count = 0
cyc_count = 0
for train_data in train_data_list:
    dataset = get_dataset(train_data)
    
    for batch in dataset.shuffle(75).take(1):
        _class = batch['groundtruth_classes'].numpy()
        
        veh_count += np.count_nonzero(_class == 1)
        ped_count += np.count_nonzero(_class == 2)
        cyc_count += np.count_nonzero(_class == 4)
#         print(veh_count)
        # only randomly get one per dataset to reduce the needed time to run
        break
        
plot_count = {'vehicle': veh_count, 'pedestrian': ped_count, 'cyclist': cyc_count}
_data = np.arange(len(plot_count))
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(_data, plot_count.values(), width = 1, align='center')
plt.xlabel('class')
plt.ylabel('count')
plt.show()
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# INFO:tensorflow:Reading unweighted datasets: ['data/train/segment-10963653239323173269_1924_000_1944_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['data/train/segment-10963653239323173269_1924_000_1944_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# INFO:tensorflow:Reading unweighted datasets: ['data/train/segment-11017034898130016754_697_830_717_830_with_camera_labels.tfrecord']
# ...

# %%
val_data_list = glob.glob("data/val/*.tfrecord")

veh_count = 0
ped_count = 0
cyc_count = 0
for train_data in train_data_list:
    dataset = get_dataset(train_data)
    
    for batch in dataset.shuffle(75).take(1):
        _class = batch['groundtruth_classes'].numpy()
        
        veh_count += np.count_nonzero(_class == 1)
        ped_count += np.count_nonzero(_class == 2)
        cyc_count += np.count_nonzero(_class == 4)
#         print(veh_count)
        # only randomly get one per dataset to reduce the needed time to run
        break
        
plot_count = {'vehicle': veh_count, 'pedestrian': ped_count, 'cyclist': cyc_count}
_data = np.arange(len(plot_count))
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(_data, plot_count.values(), width = 1, align='center')
plt.xlabel('class')
plt.ylabel('count')
plt.show()
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# INFO:tensorflow:Reading unweighted datasets: ['data/train/segment-10963653239323173269_1924_000_1944_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['data/train/segment-10963653239323173269_1924_000_1944_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# INFO:tensorflow:Reading unweighted datasets: ['data/train/segment-11017034898130016754_697_830_717_830_with_camera_labels.tfrecord']
# ...
